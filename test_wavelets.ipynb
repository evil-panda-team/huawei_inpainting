# %%
import matplotlib.pyplot as plt
import pywt
import cv2

# %%
img = cv2.imread('output/dfnet/result/800.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig, axs = plt.subplots(1, 1, figsize=(
            10, 10), facecolor='w', edgecolor='k')
axs.imshow(img)
plt.show()

# %%
def waveletSmooth( x, wavelet="db4", level=1, title=None ):
    # calculate the wavelet coefficients
    coeff = pywt.wavedec( x, wavelet, mode="per" )
    # calculate a threshold
    sigma = mad( coeff[-level] )
    # changing this threshold also changes the behavior,
    # but I have not played with this very much
    uthresh = sigma * np.sqrt( 2*np.log( len( x ) ) )
    coeff[1:] = ( pywt.threshold( i, value=uthresh, mode="soft" ) for i in coeff[1:] )
    # reconstruct the signal using the thresholded coefficients
    y = pywt.waverec( coeff, wavelet, mode="per" )
    f, ax = plt.subplots()
    plot( x, color="b", alpha=0.5 )
    plot( y, color="b" )
    if title:
        ax.set_title(title)
    ax.set_xlim((0,len(y)))

# %%
img_denoised = dwt_denoise(img)
fig, axs = plt.subplots(1, 1, figsize=(
            10, 10), facecolor='w', edgecolor='k')
axs.imshow(img_denoised)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-7f095ec2955d> in <module>
# ----> 1 img_denoised = dwt_denoise(img)
#       2 fig, axs = plt.subplots(1, 1, figsize=(
#       3             10, 10), facecolor='w', edgecolor='k')
#       4 axs.imshow(img_denoised)
#       5 plt.show()
#
# <ipython-input-17-837c6e696079> in dwt_denoise(X, wavelet, levels, alpha)
#      71
#      72         for b in range(bands):
# ---> 73             out[:, :, b] = _denoise_band(X[..., b], wavelet, levels, alpha)
#      74     else:
#      75         out[:] = _denoise_band(X, wavelet, levels, alpha)
#
# <ipython-input-17-837c6e696079> in _denoise_band(X, wavelet, levels, alpha)
#       3
#       4 def _denoise_band(X, wavelet, levels, alpha):
# ----> 5     from var_est import variance
#       6
#       7     if alpha is None:
#
# ModuleNotFoundError: No module named 'var_est'
